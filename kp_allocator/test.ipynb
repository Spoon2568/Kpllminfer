# %%
import my_allocator
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import my_allocator
#
# ImportError: libc10.so: cannot open shared object file: No such file or directory
